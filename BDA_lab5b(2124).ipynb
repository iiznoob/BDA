# %% [markdown]
# <h4>Lab No 5B</h4>
# <h4 align="right">Utkarsh Bhangale<br>2020802124</h4>

# %% [markdown]
# <h4> Decision Tree

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate blobs dataset
X, y = make_blobs(n_samples=500, centers=4, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], alpha=0.8)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# Perform decision tree clustering
tree = AgglomerativeClustering(n_clusters=4, linkage='ward')
tree.fit(X)
# Out:
# AgglomerativeClustering(n_clusters=4)

# %%
# Plot the resulting clusters
plt.scatter(X[:, 0], X[:, 1], c=tree.labels_, alpha=0.8)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
